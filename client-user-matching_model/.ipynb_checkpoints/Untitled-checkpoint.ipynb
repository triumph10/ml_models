# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler,OrdinalEncoder,OneHotEncoder

# %%
client_data = pd.read_csv("Final_Upwork_Dataset.csv")

# %%
client_data.head()
# Out:
#                                            Job Title  \
# 0                      Power bi specialist freelance
# 1            Case Study (on-demand delivery startup)
# 2  File Maker Pro Reports, Charts, Query and Ongo...
# 3          Implementation of EleutherAI/gpt-neox-20b
# 4  BI and Data Engineer for Upwork Finance System...
#
#                                              Job_URL EX_level_demand  \
# 0  https://www.upwork.com/jobs/Power-specialist-f...          Expert
# 1  https://www.upwork.com/jobs/Case-Study-demand-...    Intermediate
# 2  https://www.upwork.com/jobs/File-Maker-Pro-Rep...    Intermediate
# 3  https://www.upwork.com/jobs/Implementation-Ele...          Expert
# 4  https://www.upwork.com/jobs/and-span-Data-span...          Expert
#
#                         Time_Limitation Search_Keyword     Posted_from  \
# 0                                   NaN   Data_science   5 minutes ago
# 1                                   NaN   Data_science   5 minutes ago
# ...

# %%
client_data.shape
# Out:
# (63950, 41)

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63950 entries, 0 to 63949
# Data columns (total 41 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Job Title             63948 non-null  object
#  1   Job_URL               63949 non-null  object
#  2   EX_level_demand       56935 non-null  object
#  3   Time_Limitation       23034 non-null  object
#  4   Search_Keyword        63949 non-null  object
#  5   Posted_from           63913 non-null  object
#  6   Description           63948 non-null  object
#  7   Category1_URL_search  63505 non-null  object
#  8   Category_1            63505 non-null  object
#  9   highlight             50131 non-null  object
#  10  Category2_URL_search  59889 non-null  object
#  11  Category_2            59889 non-null  object
#  12  Category3_URL_search  54997 non-null  object
#  13  Category_3            54997 non-null  object
#  14  Category4_URL_search  47543 non-null  object
# ...

# %%
client_data.isnull().sum()
# Out:
# Job Title                   2
# Job_URL                     1
# EX_level_demand          7015
# Time_Limitation         40916
# Search_Keyword              1
# Posted_from                37
# Description                 2
# Category1_URL_search      445
# Category_1                445
# highlight               13819
# Category2_URL_search     4061
# Category_2               4061
# Category3_URL_search     8953
# Category_3               8953
# Category4_URL_search    16407
# Category_4              16407
# Category5_URL_search    24372
# Category_5              24372
# Category6_URL_search    32643
# Category_6              32643
# Category7_URL_search    38758
# Category_7              38758
# Category8_URL_search    43514
# Category_8              43514
# Category9_URL_search    47469
# Category_9              47469
# Applicants_Num              1
# Payment_Situation           1
# Enterprise_Client       63897
# Freelancers_Num             0
# Spent($)                 1646
# ...

# %%
columns_to_keep = ["Job Title","EX_level_demand", "Description", "Category_1","Category_2","Category_3","Category_4","Category_5","Category_6","Category_7","Category_8","Category_9", "Rating"]
client_data = client_data[columns_to_keep]

# %%
client_data.dtypes
# Out:
# Job Title           object
# EX_level_demand     object
# Description         object
# Category_1          object
# Category_2          object
# Category_3          object
# Category_4          object
# Category_5          object
# Category_6          object
# Category_7          object
# Category_8          object
# Category_9          object
# Rating             float64
# dtype: object

# %%
client_data.describe()
# Out:
#              Rating
# count  30593.000000
# mean       4.823875
# std        0.418398
# min        1.000000
# 25%        4.842153
# 50%        4.975717
# 75%        5.000000
# max        5.000000

# %%
client_data.head()
# Out:
#                                            Job Title EX_level_demand  \
# 0                      Power bi specialist freelance          Expert
# 1            Case Study (on-demand delivery startup)    Intermediate
# 2  File Maker Pro Reports, Charts, Query and Ongo...    Intermediate
# 3          Implementation of EleutherAI/gpt-neox-20b          Expert
# 4  BI and Data Engineer for Upwork Finance System...          Expert
#
#                                          Description              Category_1  \
# 0  Already data pooled and designed. Need to refi...           Data Analysis
# 1  Hi,\n\nWould you be able to help me do a case-...      Google Data Studio
# 2  NITIAL PROJECT\n\nSet up Monthly Report mimick...          Report Writing
# 3  As a first step, you will implement the instal...  Machine Learning Model
# 4  The Upwork Finance Systems team is looking for...           Data Analysis
#
#            Category_2          Category_3       Category_4  \
# ...

# %%
print(client_data)
# Out:
#                                                Job Title EX_level_demand  \
# 0                          Power bi specialist freelance          Expert
# 1                Case Study (on-demand delivery startup)    Intermediate
# 2      File Maker Pro Reports, Charts, Query and Ongo...    Intermediate
# 3              Implementation of EleutherAI/gpt-neox-20b          Expert
# 4      BI and Data Engineer for Upwork Finance System...          Expert
# ...                                                  ...             ...
# 63945              (Commission Based) Cold Caller Needed          Expert
# 63946  High-Performance *Ecom Email* Copywriter Suppl...          Expert
# 63947                   TikTok profile managment Hungary     Entry level
# 63948  Creating videos (including UGC) for TikTok - A...    Intermediate
# 63949                                                NaN             NaN
#
#                                              Description  \
# ...

# %%
category_cols = ["Category_1", "Category_2", "Category_3", "Category_4", 
                 "Category_5", "Category_6", "Category_7", "Category_8", "Category_9"]

# %%
client_data['Merged_Category'] = client_data[category_cols].apply(
    lambda row: ', '.join(row.dropna().astype(str)), axis=1)

# %%
client_data = client_data.drop(columns=category_cols)

# %%
client_data.head()
# Out:
#                                            Job Title EX_level_demand  \
# 0                      Power bi specialist freelance          Expert
# 1            Case Study (on-demand delivery startup)    Intermediate
# 2  File Maker Pro Reports, Charts, Query and Ongo...    Intermediate
# 3          Implementation of EleutherAI/gpt-neox-20b          Expert
# 4  BI and Data Engineer for Upwork Finance System...          Expert
#
#                                          Description    Rating  \
# 0  Already data pooled and designed. Need to refi...       NaN
# 1  Hi,\n\nWould you be able to help me do a case-...  5.000000
# 2  NITIAL PROJECT\n\nSet up Monthly Report mimick...  5.000000
# 3  As a first step, you will implement the instal...  4.935536
# 4  The Upwork Finance Systems team is looking for...  4.942242
#
#                                      Merged_Category
# 0  Data Analysis, Data Visualization, Microsoft P...
# 1  Google Data Studio, SQL, Tableau, Microsoft Ex...
# ...

# %%
client_data.isnull().sum()
# Out:
# Job Title              2
# EX_level_demand     7015
# Description            2
# Rating             33357
# Merged_Category        0
# dtype: int64

# %%
columns_to_keep = ["Job Title", "Description", "Merged_Category","EX_level_demand"]
client_data = client_data[columns_to_keep]

# %%
client_data.head()
# Out:
#                                            Job Title  \
# 0                      Power bi specialist freelance
# 1            Case Study (on-demand delivery startup)
# 2  File Maker Pro Reports, Charts, Query and Ongo...
# 3          Implementation of EleutherAI/gpt-neox-20b
# 4  BI and Data Engineer for Upwork Finance System...
#
#                                          Description  \
# 0  Already data pooled and designed. Need to refi...
# 1  Hi,\n\nWould you be able to help me do a case-...
# 2  NITIAL PROJECT\n\nSet up Monthly Report mimick...
# 3  As a first step, you will implement the instal...
# 4  The Upwork Finance Systems team is looking for...
#
#                                      Merged_Category EX_level_demand
# 0  Data Analysis, Data Visualization, Microsoft P...          Expert
# 1  Google Data Studio, SQL, Tableau, Microsoft Ex...    Intermediate
# 2                    Report Writing, Custom Graphics    Intermediate
# ...

# %%
# Add a new column 'client_id' with numbers from 1 to the number of rows
client_data['client_id'] = range(1, len(client_data) + 1)

# %%
client_data.head()
# Out:
#                                            Job Title  \
# 0                      Power bi specialist freelance
# 1            Case Study (on-demand delivery startup)
# 2  File Maker Pro Reports, Charts, Query and Ongo...
# 3          Implementation of EleutherAI/gpt-neox-20b
# 4  BI and Data Engineer for Upwork Finance System...
#
#                                          Description  \
# 0  Already data pooled and designed. Need to refi...
# 1  Hi,\n\nWould you be able to help me do a case-...
# 2  NITIAL PROJECT\n\nSet up Monthly Report mimick...
# 3  As a first step, you will implement the instal...
# 4  The Upwork Finance Systems team is looking for...
#
#                                      Merged_Category EX_level_demand  \
# 0  Data Analysis, Data Visualization, Microsoft P...          Expert
# 1  Google Data Studio, SQL, Tableau, Microsoft Ex...    Intermediate
# 2                    Report Writing, Custom Graphics    Intermediate
# ...

# %%
columns_to_keep = ["client_id","Job Title", "Description", "Merged_Category","EX_level_demand"]
client_data = client_data[columns_to_keep]

# %%
client_data.dropna(subset=['EX_level_demand'], inplace=True)

# %%
client_data.head()
# Out:
#    client_id                                          Job Title  \
# 0          1                      Power bi specialist freelance
# 1          2            Case Study (on-demand delivery startup)
# 2          3  File Maker Pro Reports, Charts, Query and Ongo...
# 3          4          Implementation of EleutherAI/gpt-neox-20b
# 4          5  BI and Data Engineer for Upwork Finance System...
#
#                                          Description  \
# 0  Already data pooled and designed. Need to refi...
# 1  Hi,\n\nWould you be able to help me do a case-...
# 2  NITIAL PROJECT\n\nSet up Monthly Report mimick...
# 3  As a first step, you will implement the instal...
# 4  The Upwork Finance Systems team is looking for...
#
#                                      Merged_Category EX_level_demand
# 0  Data Analysis, Data Visualization, Microsoft P...          Expert
# 1  Google Data Studio, SQL, Tableau, Microsoft Ex...    Intermediate
# ...

# %%
client_data.shape
# Out:
# (56935, 5)

# %%
client_data.dropna(subset=['Job Title','Description'], inplace=True)

# %%
client_data.isnull().sum()
# Out:
# client_id          0
# Job Title          0
# Description        0
# Merged_Category    0
# EX_level_demand    0
# dtype: int64

# %%
client_data.shape
# Out:
# (56933, 5)

# %%
pip install faiss-cpu sentence-transformers pandas scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/13.7 MB 10.7 MB/s eta 0:00:02
#    ------------ --------------------------- 4.2/13.7 MB 10.1 MB/s eta 0:00:01
#    --------------- ------------------------ 5.2/13.7 MB 8.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.0/13.7 MB 7.4 MB/s eta 0:00:02
#    ------------------- -------------------- 6.6/13.7 MB 6.4 MB/s eta 0:00:02
#    ------------------- -------------------- 6.8/13.7 MB 5.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.9/13.7 MB 5.4 MB/s eta 0:00:02
#    -------------------------- ------------- 9.2/13.7 MB 5.5 MB/s eta 0:00:01
#    ------------------------------ --------- 10.5/13.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.8/13.7 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.7 MB 5.7 MB/s eta 0:00:01
# ...

# %%
client_data.duplicated().sum()
# Out:
# 0

# %%
client_data.to_csv(r'C:\Users\Siddhesh Patil\OneDrive\Desktop\Projects\model\client_data.csv', index=False)

# %%
freelance_data = pd.read_csv("dataset.csv")

# %%
freelance_data.head()
# Out:
#             name            contact_details       location  \
# 0       John Doe       john.doe@example.com       New York
# 1     Jane Smith     jane.smith@example.com  San Francisco
# 2    Bob Johnson    bob.johnson@example.com       New York
# 3    Alice Brown    alice.brown@example.com        Chicago
# 4  Michael Green  michael.green@example.com         Boston
#
#                          job_skills experience  \
# 0            Java; Big Data; Hadoop    5 years
# 1        JavaScript; React; Node.js    3 years
# 2       Java; Spring; Microservices    6 years
# 3  Python; Django; Machine Learning    4 years
# 4           Ruby; Rails; PostgreSQL    7 years
#
#                                             projects  \
# 0  Developed a big data processing system using H...
# 1  Built a real-time chat application using React...
# 2  Implemented a microservices architecture for a...
# 3  Created a machine learning model for predictiv...
# ...

# %%
freelance_data.shape
# Out:
# (120, 7)

# %%
freelance_data.describe()
# Out:
#               name       contact_details         location  \
# count          120                   120              120
# unique          45                    85               15
# top     Kyle Reese  nancy.drew@gmail.com  Los Angeles, CA
# freq             7                     3               14
#
#                     job_skills experience                    projects  \
# count                      120        120                         120
# unique                     120         15                          30
# top     Java; Big Data; Hadoop    3 years  Microservices architecture
# freq                         1         16                          17
#
#                        comments
# count                       120
# unique                       28
# top     Machine learning expert
# freq                         15

# %%
freelance_data['freelancer_id'] = range(1, len(freelance_data) + 1)

# %%
columns_to_keep2 = ["freelancer_id","job_skills","experience","projects"]
freelance_data = freelance_data[columns_to_keep2]

# %%
freelance_data.head()
# Out:
#    freelancer_id                        job_skills experience  \
# 0              1            Java; Big Data; Hadoop    5 years
# 1              2        JavaScript; React; Node.js    3 years
# 2              3       Java; Spring; Microservices    6 years
# 3              4  Python; Django; Machine Learning    4 years
# 4              5           Ruby; Rails; PostgreSQL    7 years
#
#                                             projects
# 0  Developed a big data processing system using H...
# 1  Built a real-time chat application using React...
# 2  Implemented a microservices architecture for a...
# 3  Created a machine learning model for predictiv...
# 4  Developed a scalable web application using Rub...

# %%
freelance_data.to_csv(r'C:\Users\Siddhesh Patil\OneDrive\Desktop\Projects\model\freelance_data.csv', index=False)

# %%
pip install torch torchvision torchaudio sentence-transformers
# Out:
# ...
# INFO: pip is looking at multiple versions of torchaudio to determine which version is compatible with other requirements. This could take a while.
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 12.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.4 MB 12.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 3.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import faiss
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load datasets
client_df = pd.read_csv("client.csv")
freelance_df = pd.read_csv("freelance.csv")

# Load pre-trained Sentence-BERT model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# Convert client job descriptions into embeddings
client_df["combined_text"] = client_df["Job Title"] + " " + client_df["Description"] + " " + client_df["Merged_Category"]
client_embeddings = model.encode(client_df["combined_text"].tolist(), convert_to_numpy=True)

# Convert freelancer profiles into embeddings
freelance_df["combined_text"] = freelance_df["job_skills"] + " " + freelance_df["experience"] + " " + freelance_df["projects"]
freelancer_embeddings = model.encode(freelance_df["combined_text"].tolist(), convert_to_numpy=True)

print(f"Generated {len(client_embeddings)} client embeddings and {len(freelancer_embeddings)} freelancer embeddings.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1817, in _LazyModule._get_module(self, module_name)
#    1816 try:
# -> 1817     return importlib.import_module("." + module_name, self.__name__)
#    1818 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ...

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install torch torchvision torchaudio tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
import tensorflow as tf
from sentence_transformers import SentenceTransformer

print("Torch version:", torch.__version__)
print("TensorFlow version:", tf.__version__)

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
print("Model loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\import_utils.py:1817, in _LazyModule._get_module(self, module_name)
#    1816 try:
# -> 1817     return importlib.import_module("." + module_name, self.__name__)
#    1818 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ...
