# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as mlt

# %%
df_fl = pd.read_csv("freelancers_40k.csv")

# %%
df_fl.head()
# Out:
#   Freelancer ID                                             Skills  \
# 0        F00001       ['Character Design', 'Prototyping', 'Swift']
# 1        F00002                    ['OpenCV', 'CorelDRAW', 'Jira']
# 2        F00003   ['Perl', 'React Native', 'Virtual Reality (VR)']
# 3        F00004  ['Express.js', 'Natural Language Processing (N...
# 4        F00005            ['Spatial Design', 'GitHub', 'Tableau']
#
#    Experience  Hourly Rate              Portfolio Links   Availability  \
# 0           3           30  ['https://www.berger.com/']  1-week notice
# 1           4           27        ['https://king.com/']  1-week notice
# 2           1           51    ['http://henderson.com/']      Part-time
# 3          10           79    ['http://www.jones.org/']      Immediate
# 4           6           55    ['http://www.lewis.biz/']  1-week notice
#
#         Location  Rating
# 0  East Danielle     4.2
# 1      East Lisa     4.4
# 2    Lake Rachel     4.0
# 3     Susanshire     4.9
# 4      Dianeside     4.9

# %%
df_fl.shape
# Out:
# (40000, 8)

# %%
df_fl.info
# Out:
# <bound method DataFrame.info of       Freelancer ID                                             Skills  \
# 0            F00001       ['Character Design', 'Prototyping', 'Swift']
# 1            F00002                    ['OpenCV', 'CorelDRAW', 'Jira']
# 2            F00003   ['Perl', 'React Native', 'Virtual Reality (VR)']
# 3            F00004  ['Express.js', 'Natural Language Processing (N...
# 4            F00005            ['Spatial Design', 'GitHub', 'Tableau']
# ...             ...                                                ...
# 39995        F39996         ['Game UI/UX', 'WebXR', 'Shell Scripting']
# 39996        F39997  ['Motion Design', 'Cross-Browser Testing', 'In...
# 39997        F39998                ['Puppeteer', 'Power BI', 'Pandas']
# 39998        F39999            ['Game Design', '3D Modeling', 'WebXR']
# 39999        F40000  ['Machine Learning', 'Google Cloud', 'Game Dev...
#
#        Experience  Hourly Rate               Portfolio Links   Availability  \
# 0               3           30   ['https://www.berger.com/']  1-week notice
# 1               4           27         ['https://king.com/']  1-week notice
# 2               1           51     ['http://henderson.com/']      Part-time
# 3              10           79     ['http://www.jones.org/']      Immediate
# 4               6           55     ['http://www.lewis.biz/']  1-week notice
# ...           ...          ...                           ...            ...
# 39995           6          137   ['http://www.hoffman.com/']      Part-time
# 39996           3          101       ['http://snyder.info/']      Immediate
# 39997           2          147  ['https://gordon-tran.com/']  1-week notice
# 39998           3           42   ['https://www.garcia.com/']      Part-time
# 39999           9           37    ['https://www.gomez.com/']      Immediate
#
#                 Location  Rating
# 0          East Danielle     4.2
# 1              East Lisa     4.4
# 2            Lake Rachel     4.0
# 3             Susanshire     4.9
# 4              Dianeside     4.9
# ...                  ...     ...
# 39995           Wardberg     4.0
# 39996      Cristinamouth     4.5
# 39997        Adrianmouth     4.5
# 39998          Wolfhaven     3.7
# 39999  North Rachelburgh     4.6
#
# [40000 rows x 8 columns]>

# %%
df_fl.describe()
# Out:
#          Experience   Hourly Rate        Rating
# count  40000.000000  40000.000000  40000.000000
# mean       5.503375     84.715475      4.247578
# std        2.871210     37.921655      0.434434
# min        1.000000     20.000000      3.500000
# 25%        3.000000     52.000000      3.900000
# 50%        6.000000     85.000000      4.200000
# 75%        8.000000    118.000000      4.600000
# max       10.000000    150.000000      5.000000

# %%
df_fl.isnull().sum()
# Out:
# Freelancer ID      0
# Skills             0
# Experience         0
# Hourly Rate        0
# Portfolio Links    0
# Availability       0
# Location           0
# Rating             0
# dtype: int64

# %%
columns_to_keep = ["Freelancer ID","Skills","Experience","Hourly Rate","Rating"]
df_fl = df_fl[columns_to_keep]

# %%
df_fl.head()
# Out:
#   Freelancer ID                                             Skills  \
# 0        F00001       ['Character Design', 'Prototyping', 'Swift']
# 1        F00002                    ['OpenCV', 'CorelDRAW', 'Jira']
# 2        F00003   ['Perl', 'React Native', 'Virtual Reality (VR)']
# 3        F00004  ['Express.js', 'Natural Language Processing (N...
# 4        F00005            ['Spatial Design', 'GitHub', 'Tableau']
#
#    Experience  Hourly Rate  Rating
# 0           3           30     4.2
# 1           4           27     4.4
# 2           1           51     4.0
# 3          10           79     4.9
# 4           6           55     4.9

# %%
import pandas as pd
from collections import Counter

# Extract and clean skills
skills = df_fl["Skills"].str.lower().str.split(", ").explode().str.strip()

# Find unique skills and counts
skill_counts = Counter(skills)
print("Unique skills:", skill_counts.keys())
print("Skill frequencies:", skill_counts.most_common())
# Out:
# Unique skills: dict_keys(["['character design'", "'prototyping'", "'swift']", "['opencv'", "'coreldraw'", "'jira']", "['perl'", "'react native'", "'virtual reality (vr)']", "['express.js'", "'natural language processing (nlp)'", "'tableau']", "['spatial design'", "'github'", "['user research'", "'keras'", "'cloud security']", "['parametric design tools'", "'selenium'", "'generative ai tools']", "['swift'", "'webrtc'", "'responsive web design']", "['indesign'", "'rest api'", "'industrial design basics']", "['nosql'", "'python'", "'augmented reality (ar)']", "['openshift'", "'motion design'", "'svelte']", "['voice user interface (vui)'", "'devops'", "'motion design']", "['style guides'", "'version control'", "'mongodb']", "['generative ai tools'", "'google colab'", "'deep learning']", "['next.js'", "'flutter'", "'premiere pro']", "['canva'", "'behavioral design']", "['firebase'", "'shell scripting'", "'design psychology']", "['svelte'", "'docker'", "'opencv']", "['data visualization'", "'information architecture'", "'pandas']", "'blender'", "'affinity designer']", "['brand identity'", "'after effects'", "'css']", "['api testing'", "'storyboarding'", "'raspberry pi']", "['iam (identity and access management)'", "'mobile app development'", "'openai api']", "'confluence']", "['flask'", "'game ui/ux'", "'design thinking']", "['sass/scss'", "'node.js'", "'solidity']", "['behavioral design'", "'bash scripting'", "'storyboarding']", "['game design'", "'solidity'", "'animation']", "['kotlin'", "'pytorch'", "'docker']", "['spark'", "'arduino'", "'data visualization']", "['figma'", "'openai api'", "'nosql']", "'firebase'", "'3d modeling']", "['tableau'", "'industrial design basics'", "'data warehousing']", "['design psychology'", "'bootstrap'", "'nuxt.js']", "['web design'", "'design thinking'", "'agile methodology']", "['serverless architecture'", "'brand identity'", "'ui animation']", "['google colab'", "'websockets'", "'postgresql']", "['google cloud'", "'ruby']", "['powershell'", "'voice user interface (vui)'", "['algorithms'", "'usability testing'", "'blockchain basics']", "['hadoop'", "'svelte'", "'mysql']", "['maya'", "'interaction design'", "'version control']", "['raspberry pi'", "'snowflake'", "'swagger']", "['ruby'", "'apis and microservices']", "['c#'", "'pandas'", "'game design'", "'cross-browser testing']", "['matplotlib'", "'wireframing'", "['nuxt.js'", "'c'", "['graphql'", "'system design'", "'iot (internet of things)']", "['computer vision'", "'logo design'", "'advanced motion graphics']", "['microinteraction design'", "'redis'", "['cross-browser testing'", "'owasp'", "'git'", "['interaction design'", "'design psychology'", "'html']", "['penetration testing'", "'microinteraction design'", "'powershell']", "'web design'", "'video editing']", "['cybersecurity basics'", "'grpc'", "'react native']", "['information architecture'", "'tensorflow']", "['openai api'", "'augmented reality (ar) design']", "['c'", "'power bi'", "'kotlin']", "'ansible'", "'devops']", "['video editing'", "'virtual reality (vr) design'", "'maya']", "['web accessibility (wcag)'", "['git'", "'javascript'", "'color theory']", "['tailwind css'", "'automated testing'", "'ux design']", "['selenium'", "'cybersecurity basics'", "'logo design']", "'ui animation'", "'graphic design']", "['shell scripting'", "'generative ai tools'", "'mobile app development']", "['java'", "'terraform'", "['game ui/ux'", "'responsive design'", "'embedded systems'", "['azure'", "'jenkins']", "'sass/scss'", "'game development']", "['coreldraw'", "'flask'", "['rest api'", "'microinteraction design']", "['python'", "'performance optimization']", "['ui design'", "'iot (internet of things)'", "'automated testing']", "'express.js'", "'adobe xd'", "'react']", "'advanced motion graphics'", "['augmented reality (ar) design'", "'machine learning'", "'user research'", "['ethereum'", "['cloud security'", "'openshift'", "'real-time 3d design']", "'tensorflow'", "'azure']", "'tailwind css'", "'ke ...
# Skill frequencies: [("['game development'", 257), ("['aws'", 255), ("'python'", 253), ("'sketch']", 253), ("'power bi']", 252), ("'tailwind css']", 252), ("['motion design'", 252), ("'graphic design']", 251), ("['data visualization'", 250), ("['opencv'", 246), ("['postman'", 246), ("['google colab'", 244), ("['tensorflow'", 244), ("'augmented reality (ar) design']", 243), ("'tableau']", 242), ("'mobile app development'", 242), ("'puppeteer']", 242), ("'django'", 242), ("['augmented reality (ar) design'", 241), ("'css'", 241), ("'azure'", 241), ("['figma'", 240), ("'google cloud'", 240), ("'web accessibility']", 240), ("'angular'", 240), ("['interaction design'", 239), ("'mongodb'", 239), ("'openai api']", 238), ("'ruby']", 238), ("['c#'", 238), ("'ui animation'", 238), ("'brand identity']", 238), ("['after effects'", 238), ("['react'", 238), ("['nuxt.js'", 237), ("'spatial design']", 237), ("'ethical hacking'", 237), ("['spatial design'", 236), ("['web accessibility (wcag)'", 236), ("['django'", 236), ("'augmented reality (ar)']", 235), ("'storyboarding']", 235), ("['mobile app development'", 235), ("'aws']", 235), ("'bootstrap']", 235), ("['adobe photoshop'", 235), ("'motion design']", 234), ("'tensorflow']", 234), ("['ci/cd'", 234), ("'natural language processing (nlp)']", 234), ("['version control'", 234), ("'nosql'", 234), ("'vue.js']", 234), ("'bash scripting']", 234), ("['iam (identity and access management)'", 233), ("'web design'", 233), ("'figma']", 233), ("['usability testing'", 233), ("['unity'", 233), ("'devops'", 232), ("'design thinking']", 232), ("'data visualization']", 232), ("'confluence'", 232), ("'cross-browser testing'", 232), ("'design psychology']", 231), ("['sass/scss'", 231), ("['tableau'", 231), ("'embedded systems'", 231), ("'flutter']", 231), ("'usability testing']", 231), ("'c']", 231), ("'etl'", 231), ("'keras'", 230), ("['firebase'", 230), ("'animation']", 230), ("'agile methodology']", 230), ("'mysql']", 230), ("'logo design'", 230), ("'maya']", 230), ("'augmented reality (ar) design'", 230), ("'api testing']", 230), ("'kubernetes'", 230), ("'ux design'", 230), ("['postgresql'", 230), ("'kotlin'", 230), ("['iot (internet of things)'", 230), ("['character design'", 229), ("'github'", 229), ("'solidity']", 229), ("['python'", 229), ("'keras']", 229), ("'aws'", 229), ("'unreal engine'", 229), ("'print design']", 229), ("'performance optimization'", 229), ("'sql'", 229), ("['data structures'", 229), ("'responsive web design'", 229), ("['agile methodology'", 229), ("'information architecture']", 229), ("'react native'", 228), ("'firebase'", 228), ("'industrial design basics'", 228), ("'hadoop'", 228), ("['owasp'", 228), ("'mobile app design']", 228), ("'data warehousing']", 227), ("'apis and microservices']", 227), ("['graphql'", 227), ("'microinteraction design'", 227), ("['java'", 227), ("'jquery']", 227), ("['design systems'", 227), ("['flutter'", 227), ("'maya'", 227), ("'webxr']", 227), ("'ui design'", 227), ("'penetration testing']", 227), ("'responsive design']", 227), ("'rest api'", 226), ("'version control'", 226), ("['kotlin'", 226), ("'iot (internet of things)']", 226), ("['tailwind css'", 226), ("'microinteraction design']", 226), ("'api testing'", 226), ("'blockchain basics'", 226), ("['system design'", 226), ("'generative design'", 226), ("['cypress'", 226), ("'voice user interface (vui)']", 226), ("'responsive web design']", 225), ("'pandas']", 225), ("'tailwind css'", 225), ("['data warehousing'", 225), ("['ux design'", 225), ("'cloudformation']", 225), ("'cybersecurity basics']", 225), ("'vue.js'", 225), ("'cinema 4d'", 225), ("'shell scripting']", 225), ("'next.js'", 225), ("'ethereum']", 225), ("['express.js'", 224), ("'flutter'", 224), ("'storyboarding'", 224), ("'pytorch'", 224), ("'power bi'", 224), ("'cybersecurity basics'", 224), ("['game ui/ux'", 224), ("'opencv'", 224), ("'owasp']", 224), ("'parametric design tools']", 224), ("'prototyping']", 224), ("'ci/cd'", 224), ("'rest ...

# %%
import matplotlib.pyplot as plt

# Assuming skill_counts is your Counter object from previous code
skills = list(skill_counts.keys())
counts = list(skill_counts.values())

# Sort by count if needed for better visualization
sorted_skills, sorted_counts = zip(*sorted(zip(skills, counts), key=lambda pair: pair[1], reverse=True))

# Plotting
plt.figure(figsize=(20, 10))
plt.bar(sorted_skills[:50], sorted_counts[:50])  # Show top 50 skills for clarity
plt.xlabel('Skills')
plt.ylabel('Frequency')
plt.title('Frequency of Skills')
plt.xticks(rotation=90)  # Rotate labels to avoid overlap
plt.tight_layout()
plt.show()

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\siddhesh patil\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(type(skill_counts))
print(skill_counts)
# Out:
# <class 'collections.Counter'>
# Counter({"['game development'": 257, "['aws'": 255, "'python'": 253, "'sketch']": 253, "'power bi']": 252, "'tailwind css']": 252, "['motion design'": 252, "'graphic design']": 251, "['data visualization'": 250, "['opencv'": 246, "['postman'": 246, "['google colab'": 244, "['tensorflow'": 244, "'augmented reality (ar) design']": 243, "'tableau']": 242, "'mobile app development'": 242, "'puppeteer']": 242, "'django'": 242, "['augmented reality (ar) design'": 241, "'css'": 241, "'azure'": 241, "['figma'": 240, "'google cloud'": 240, "'web accessibility']": 240, "'angular'": 240, "['interaction design'": 239, "'mongodb'": 239, "'openai api']": 238, "'ruby']": 238, "['c#'": 238, "'ui animation'": 238, "'brand identity']": 238, "['after effects'": 238, "['react'": 238, "['nuxt.js'": 237, "'spatial design']": 237, "'ethical hacking'": 237, "['spatial design'": 236, "['web accessibility (wcag)'": 236, "['django'": 236, "'augmented reality (ar)']": 235, "'storyboarding']": 235, "['mobile app development'": 235, "'aws']": 235, "'bootstrap']": 235, "['adobe photoshop'": 235, "'motion design']": 234, "'tensorflow']": 234, "['ci/cd'": 234, "'natural language processing (nlp)']": 234, "['version control'": 234, "'nosql'": 234, "'vue.js']": 234, "'bash scripting']": 234, "['iam (identity and access management)'": 233, "'web design'": 233, "'figma']": 233, "['usability testing'": 233, "['unity'": 233, "'devops'": 232, "'design thinking']": 232, "'data visualization']": 232, "'confluence'": 232, "'cross-browser testing'": 232, "'design psychology']": 231, "['sass/scss'": 231, "['tableau'": 231, "'embedded systems'": 231, "'flutter']": 231, "'usability testing']": 231, "'c']": 231, "'etl'": 231, "'keras'": 230, "['firebase'": 230, "'animation']": 230, "'agile methodology']": 230, "'mysql']": 230, "'logo design'": 230, "'maya']": 230, "'augmented reality (ar) design'": 230, "'api testing']": 230, "'kubernetes'": 230, "'ux design'": 230, "['postgresql'": 230, "'kotlin'": 230, "['iot (internet of things)'": 230, "['character design'": 229, "'github'": 229, "'solidity']": 229, "['python'": 229, "'keras']": 229, "'aws'": 229, "'unreal engine'": 229, "'print design']": 229, "'performance optimization'": 229, "'sql'": 229, "['data structures'": 229, "'responsive web design'": 229, "['agile methodology'": 229, "'information architecture']": 229, "'react native'": 228, "'firebase'": 228, "'industrial design basics'": 228, "'hadoop'": 228, "['owasp'": 228, "'mobile app design']": 228, "'data warehousing']": 227, "'apis and microservices']": 227, "['graphql'": 227, "'microinteraction design'": 227, "['java'": 227, "'jquery']": 227, "['design systems'": 227, "['flutter'": 227, "'maya'": 227, "'webxr']": 227, "'ui design'": 227, "'penetration testing']": 227, "'responsive design']": 227, "'rest api'": 226, "'version control'": 226, "['kotlin'": 226, "'iot (internet of things)']": 226, "['tailwind css'": 226, "'microinteraction design']": 226, "'api testing'": 226, "'blockchain basics'": 226, "['system design'": 226, "'generative design'": 226, "['cypress'": 226, "'voice user interface (vui)']": 226, "'responsive web design']": 225, "'pandas']": 225, "'tailwind css'": 225, "['data warehousing'": 225, "['ux design'": 225, "'cloudformation']": 225, "'cybersecurity basics']": 225, "'vue.js'": 225, "'cinema 4d'": 225, "'shell scripting']": 225, "'next.js'": 225, "'ethereum']": 225, "['express.js'": 224, "'flutter'": 224, "'storyboarding'": 224, "'pytorch'": 224, "'power bi'": 224, "'cybersecurity basics'": 224, "['game ui/ux'": 224, "'opencv'": 224, "'owasp']": 224, "'parametric design tools']": 224, "'prototyping']": 224, "'ci/cd'": 224, "'rest api']": 224, "'lightroom'": 224, "'google colab'": 223, "'redis'": 223, "'html']": 223, "'terraform'": 223, "'openshift'": 223, "'canva']": 223, "'puppeteer'": 223, "'tableau'": 223, "'php'": 223, "'angular']": 223, "['voice user interface (vui)'": 222, "'websockets'": 222, "['penetration testing'": 222, "'user research ...

# %%
from collections import Counter

# Assuming skill_counts is a list of tuples or similar structure
skill_counts = Counter(dict(skill_counts))

# %%
# Convert float keys to strings if necessary
skill_counts = {str(k): v for k, v in skill_counts.items()}

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Assuming skill_counts is now correctly formatted
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(skill_counts)

plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Skills Word Cloud')
plt.show()

# %%
new = pd.read_csv("freelancers_dataset_specialized_new.csv")

# %%
new.head()
# Out:
#   Freelancer_ID                                             Skills  \
# 0         F0001  Mobile Development: hybrid app development, an...
# 1         F0002  Education & Training: training online lms, lea...
# 2         F0003  Cybersecurity: information security consultati...
# 3         F0004  Education & Training: training, teaching; Gene...
# 4         F0005  DevOps: azure blockchain service, azure app se...
#
#   Experience_Level  Years_of_Experience  \
# 0      Entry Level                    4
# 1     Intermediate                    3
# 2     Intermediate                    6
# 3           Expert                   12
# 4     Intermediate                    5
#
#                                          Description  \
# 0  Entry Level Mobile Development professional wi...
# 1  Intermediate Education & Training professional...
# 2  Intermediate Cybersecurity professional with e...
# 3  Expert Education & Training professional with ...
# 4  Intermediate DevOps professional with experien...
#
#                                             Projects  Budget_Hourly  \
# 0      There go any water only event. for George Ltd              6
# 1  For too information. for Smith LLC; Reduce sou...             18
# 2  Include quality stay. for Hill and Sons; Watch...             15
# 3  Yet response family green these. for Brown-Mor...             39
# 4  Defense myself foot both since. for Stone-Gain...             15
#
#   Budget_Project   Location
# 0      $236-$859    Kolkata
# 1     $514-$2068       Pune
# 2    $1336-$2228       Pune
# 3    $4680-$7568  Bangalore
# 4    $1410-$2586    Kolkata

# %%
new.shape
# Out:
# (10000, 9)

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Freelancer_ID        10000 non-null  object
#  1   Skills               10000 non-null  object
#  2   Experience_Level     10000 non-null  object
#  3   Years_of_Experience  10000 non-null  int64
#  4   Description          10000 non-null  object
#  5   Projects             10000 non-null  object
#  6   Budget_Hourly        10000 non-null  int64
#  7   Budget_Project       10000 non-null  object
#  8   Location             10000 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 703.3+ KB

# %%
import pandas as pd
from collections import Counter

# Extract and clean skills
skills2 = new["Skills"].str.lower().str.split(", ").explode().str.strip()

# Find unique skills and counts
skill_counts2 = Counter(skills2)
print("Unique skills:", skill_counts2.keys())
print("Skill frequencies:", skill_counts2.most_common())
# Out:
# Unique skills: dict_keys(['mobile development: hybrid app development', 'android app development', 'mobile app design', 'mobile app redesign; general:', 'education & training: training online lms', 'learning theory', 'teaching spanish; general:', 'cybersecurity: information security consultation', 'vpn', 'security testing; general: agile', 'project management', 'education & training: training', 'teaching; general: git', 'devops: azure blockchain service', 'azure app service; general:', 'database management: database programming', 'database development; general: git', 'education & training: program evaluation', 'executive coaching', 'curriculum development', 'curriculum design; general: project management', 'business & consulting: business planning & strategy', 'business analysis; general:', 'education & training: training design', 'academic proofreading; general:', 'database management: oracle database administration', 'sql programming; general:', 'ui/ux design: user interface design', 'prototyping', 'ux & ui', 'mobile ui design; general: git', 'agile', 'cybersecurity: firewall', 'source code scanning; general:', 'database management: transact-sql', 'database architecture', 'data warehousing; general: git', 'sql', 'writing & content creation: product documentation', 'ebook writing; general: project management', 'data science: bayesian statistics', 'hypothesis testing', 'data analysis; general: sql', 'database management: mariadb', 'mysql', 'sql; general: project management', 'ui/ux design: ux copy', 'visual communication; general:', 'database management: oracle database', 'sql; general:', 'web development: software developer', 'software architecture & design; general:', 'translation & languages: greek', 'french to english translation', 'english to italian translation; general: project management', 'marketing & seo: linkedin marketing', 'google ads', 'google tag manager', 'analytics & tracking setup; general:', 'business & consulting: organizational design & effectiveness', 'business modeling', 'business innovation; general: agile', 'writing & content creation: article writing', 'journalism writing', 'content seo', 'content analysis; general: git', 'api', 'translation & languages: english to danish translation', 'vietnamese', 'swedish', 'french to german translation; general:', 'marketing & seo: social media engagement', 'content writing; general: git', 'writing & content creation: blog writing', 'blog content', 'creative writing; general: git', 'security testing', 'security infrastructure; general:', 'writing & content creation: social media content', 'academic writing; general: api', 'marketing & seo: email marketing', 'social media marketing', 'seo keyword research', 'search engine optimization; general: git', 'education & training: training presentation', 'training', 'academic content development', 'program management; general: api', 'business & consulting: business modeling', 'business consulting; general:', 'marketing & seo: analytics & tracking setup', 'content writing; general:', 'web development: virtual reality', 'api documentation', 'gatsby.js; general: git', 'education & training: teaching english', 'exam preparation', 'program evaluation', 'training plan; general: project management', 'ui/ux design: design enhancement', 'user interface design; general:', 'education & training: education', 'higher education', 'instructional design', 'tutoring; general: sql', 'devops: devops', 'openshift', 'serverless computing', 'azure cosmos db; general: api', 'business & consulting: sales development', 'corporate strategy', 'business writing', 'corporate governance; general:', 'database management: mongodb', 'oracle database; general:', 'marketing & seo: google analytics', 'ecommerce marketing', 'seo strategy; general: git', 'business & consulting: brand consulting', 'sales leadership; general: project management', 'project management: team management', 'project timelines', 'digital project management', 'project delivery; general: ...
# Skill frequencies: [('sql', 707), ('api', 684), ('project management', 677), ('agile', 668), ('git', 648), ('visual communication', 62), ('mysql', 56), ('ux & ui', 51), ('adobe xd', 51), ('vpn', 50), ('security testing', 50), ('cybersecurity: network security', 50), ('security policies & procedures documentation', 49), ('ui/ux design: usability testing', 49), ('design enhancement', 49), ('mobile app testing', 49), ('ui/ux design: ui/ux prototyping', 48), ('mobile development: swift', 48), ('cybersecurity: information security consultation', 47), ('ui/ux design: ux copy', 47), ('cybersecurity: web application security', 47), ('ui/ux design: user experience strategy', 47), ('ui/ux design: design enhancement', 46), ('user experience design', 46), ('figma', 46), ('ios development', 46), ('mobile app redesign', 46), ('ui/ux design: prototyping', 46), ('ui/ux design: user interface design', 45), ('cybersecurity: cyber threat intelligence', 45), ('content writing', 45), ('wireframing', 45), ('ui/ux design: mobile ui design', 44), ('cybersecurity: encryption', 44), ('cybersecurity: security infrastructure', 43), ('ui/ux design: wireframing', 43), ('cybersecurity: information security', 43), ('cybersecurity: security assessment & testing', 43), ('cybersecurity: ethical hacking', 43), ('project management: project scheduling', 43), ('mobile development: mobile app design', 43), ('database management: sql programming', 43), ('cybersecurity: security testing', 43), ('prototyping', 42), ('content seo', 42), ('source code scanning', 42), ('mobile development: flutter', 42), ('ui/ux design: user experience design', 42), ('cybersecurity: security policies & procedures documentation', 42), ('mobile development: ios development', 42), ('database management: database programming', 41), ('cybersecurity: firewall', 41), ('usability testing', 41), ('ui/ux design: ux & ui', 41), ('swift', 41), ('cybersecurity: cybersecurity management', 41), ('agile project management', 41), ('penetration testing', 41), ('project management: requirements specification', 41), ('sql server integration services', 40), ('cybersecurity: vpn', 40), ('ethical hacking', 40), ('personal information protection & electronic documents act', 40), ('android sdk', 40), ('mobile development: hybrid app development', 39), ('database management: mongodb', 39), ('security assessment & testing', 39), ('devops: azure iot core', 39), ('milestones', 39), ('user experience strategy', 39), ('database management: sql server integration services', 39), ('ui/ux design: visual communication', 39), ('data modeling', 39), ('database management: sql', 39), ('ui/ux design: user research', 39), ('ui/ux design: adobe xd', 39), ('database management: database administration', 39), ('android app development', 38), ('database management: mariadb', 38), ('project delivery', 38), ('responsive design', 38), ('cyber threat intelligence', 38), ('project management: project management professional', 38), ('scrum', 38), ('mobile development: ios', 38), ('security infrastructure', 38), ('mobile ui design', 38), ('database management', 38), ('ux wireframe', 38), ('database development', 38), ('ui/ux prototyping', 37), ('cybersecurity: source code scanning', 37), ('web application security', 37), ('information security', 37), ('network security', 37), ('database management: microsoft sql server administration', 37), ('database programming', 37), ('cybersecurity: penetration testing', 37), ('nosql database', 36), ('mobile development: react native', 36), ('mobile development: android sdk', 36), ('firewall', 36), ('ui/ux design: figma', 36), ('ui/ux design: responsive design', 36), ('mobile development: mobile app improvement', 36), ('data warehousing', 36), ('encryption', 36), ('cybersecurity management', 36), ('database management: nosql database', 36), ('react native', 36), ('database design', 36), ('ionic framework', 36), ('mobile development: mobile app development', 36), ('project management: project delivery ...

# %%
import matplotlib.pyplot as plt

# Assuming skill_counts is your Counter object from previous code
skills2 = list(skill_counts2.keys())
counts2 = list(skill_counts2.values())

# Sort by count if needed for better visualization
sorted_skills2, sorted_counts2 = zip(*sorted(zip(skills2, counts2), key=lambda pair: pair[1], reverse=True))

# Plotting
plt.figure(figsize=(20, 10))
plt.bar(sorted_skills2[:50], sorted_counts2[:50])  # Show top 50 skills for clarity
plt.xlabel('Skills')
plt.ylabel('Frequency')
plt.title('Frequency of Skills')
plt.xticks(rotation=90)  # Rotate labels to avoid overlap
plt.tight_layout()
plt.show()
